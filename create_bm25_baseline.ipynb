# %%
import pandas as pd  

data = pd.read_csv("data/parsed_docs.csv")
data = data[:10]

# %%
import spacy 
from spacy.lang.en.stop_words import STOP_WORDS
import re
import swifter

def clean_lemmatize(text):
    clean_text = re.sub(r'[^\w\s]', '', text.lower())
    toks = [tok.lemma_ for tok in nlp(clean_text) if tok.text.strip() != ""]
    return toks

data["tokens"] = data["text"].swifter.apply(lambda x: clean_lemmatize(x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.conda/envs/nlp-env/lib/python3.7/site-packages/swifter/swifter.py in apply(self, func, convert_dtype, args, **kwds)
#     249             with suppress_stdout_stderr():
# --> 250                 tmp_df = func(sample, *args, **kwds)
#     251                 sample_df = sample.apply(func, convert_dtype=convert_dtype, args=args, **kwds)
#
# <ipython-input-29-681010417806> in <lambda>(x)
#      10
# ---> 11 data["tokens"] = data["text"].swifter.apply(lambda x: clean_lemmatize(x))
#
# <ipython-input-29-681010417806> in clean_lemmatize(text)
#       6 def clean_lemmatize(text):
# ----> 7     clean_text = re.sub(r'[^\w\s]', '', text.lower())
#       8     toks = [tok.lemma_ for tok in nlp(clean_text) if tok.text.strip() != ""]
#
# ~/.conda/envs/nlp-env/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#
# AttributeError: 'Series' object has no attribute 'lower'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-681010417806> in <module>
#       9     return toks
#      10
# ---> 11 data["tokens"] = data["text"].swifter.apply(lambda x: clean_lemmatize(x))
#
# ~/.conda/envs/nlp-env/lib/python3.7/site-packages/swifter/swifter.py in apply(self, func, convert_dtype, args, **kwds)
#     257         except ERRORS_TO_HANDLE:  # if can't vectorize, estimate time to pandas apply
#     258             wrapped = self._wrapped_apply(func, convert_dtype=convert_dtype, args=args, **kwds)
# --> 259             timed = timeit.timeit(wrapped, number=N_REPEATS)
#     260             sample_proc_est = timed / N_REPEATS
#     261             est_apply_duration = sample_proc_est / self._SAMPLE_SIZE * self._obj.shape[0]
#
# ~/.conda/envs/nlp-env/lib/python3.7/timeit.py in timeit(stmt, setup, timer, number, globals)
#     230            number=default_number, globals=None):
#     231     """Convenience function to create Timer object and call timeit method."""
# --> 232     return Timer(stmt, setup, timer, globals).timeit(number)
#     233
#     234 def repeat(stmt="pass", setup="pass", timer=default_timer,
#
# ~/.conda/envs/nlp-env/lib/python3.7/timeit.py in timeit(self, number)
#     174         gc.disable()
#     175         try:
# --> 176             timing = self.inner(it, self.timer)
#     177         finally:
#     178             if gcold:
#
# ~/.conda/envs/nlp-env/lib/python3.7/timeit.py in inner(_it, _timer, _stmt)
#
# ~/.conda/envs/nlp-env/lib/python3.7/site-packages/swifter/swifter.py in wrapped()
#     181         def wrapped():
#     182             with suppress_stdout_stderr():
# --> 183                 self._obj.iloc[: self._SAMPLE_SIZE].apply(func, convert_dtype=convert_dtype, args=args, **kwds)
#     184
#     185         return wrapped
#
# ~/.conda/envs/nlp-env/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4211             else:
#    4212                 values = self.astype(object)._values
# -> 4213                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4214
#    4215         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-29-681010417806> in <lambda>(x)
#       9     return toks
#      10
# ---> 11 data["tokens"] = data["text"].swifter.apply(lambda x: clean_lemmatize(x))
#
# <ipython-input-29-681010417806> in clean_lemmatize(text)
#       6 def clean_lemmatize(text):
#       7     clean_text = re.sub(r'[^\w\s]', '', text.lower())
# ----> 8     toks = [tok.lemma_ for tok in nlp(clean_text) if tok.text.strip() != ""]
#       9     return toks
#      10
#
# ~/.conda/envs/nlp-env/lib/python3.7/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     985             component_cfg = {}
#     986         for name, proc in self.pipeline:
# --> 987             if name in disable:
#     988                 continue
#     989             if not hasattr(proc, "__call__"):
#
# KeyboardInterrupt:
